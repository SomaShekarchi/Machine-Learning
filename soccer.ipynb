# %%
import pandas as pd
data_frame=pd.read_csv('Fifa_world_cup_matches.csv')
data_frame.shape
# Out:
# (64, 88)

# %%
data_frame.describe()
# Out:
#        number of goals team1  number of goals team2  total attempts team1  \
# count              64.000000              64.000000             64.000000
# mean                1.578125               1.109375             11.140625
# std                 1.551289               1.055856              4.972519
# min                 0.000000               0.000000              2.000000
# 25%                 0.000000               0.000000              8.000000
# 50%                 1.000000               1.000000             10.000000
# 75%                 2.000000               2.000000             14.000000
# max                 7.000000               4.000000             25.000000
#
#        total attempts team2  conceded team1  conceded team2  \
# count             64.000000       64.000000       64.000000
# mean              11.281250        1.109375        1.578125
# std                5.807682        1.055856        1.551289
# ...

# %%
data_frame.values
# Out:
# array([['QATAR', 'ECUADOR', '42%', ..., 72, 256, 279],
#        ['ENGLAND', 'IRAN', '72%', ..., 72, 139, 416],
#        ['SENEGAL', 'NETHERLANDS', '44%', ..., 73, 263, 251],
#        ...,
#        ['FRANCE', 'MOROCCO', '34%', ..., 47, 328, 218],
#        ['CROATIA', 'MOROCCO', '45%', ..., 72, 288, 277],
#        ['ARGENTINA', 'FRANCE', '46%', ..., 104, 280, 409]], dtype=object)

# %%
data_frame[data_frame["team2"]=="FRANCE"].head()
# Out:
#         team1   team2 possession team1 possession team2 possession in contest  \
# 37    TUNISIA  FRANCE              30%              56%                   14%
# 59    ENGLAND  FRANCE              54%              36%                   10%
# 63  ARGENTINA  FRANCE              46%              40%                   14%
#
#     number of goals team1  number of goals team2         date     hour  \
# 37                      1                      0  30 NOV 2022  16 : 00
# 59                      1                      2  10 DEC 2022  20 : 00
# 63                      3                      3  18 DEC 2022  16 : 00
#
#          category  ...  penalties scored team1  penalties scored team2  \
# 37        Group D  ...                       0                       0
# 59  Quarter-final  ...                       1                       0
# 63          Final  ...                       1                       2
#
#     goal preventions team1  goal preventions team2  own goals team1  \
# ...

# %%
df1=pd.DataFrame(data_frame,columns=['team1','team2'])
df1
# Out:
#             team1         team2
# 0           QATAR       ECUADOR
# 1         ENGLAND          IRAN
# 2         SENEGAL   NETHERLANDS
# 3   UNITED STATES         WALES
# 4       ARGENTINA  SAUDI ARABIA
# ..            ...           ...
# 59        ENGLAND        FRANCE
# 60      ARGENTINA       CROATIA
# 61         FRANCE       MOROCCO
# 62        CROATIA       MOROCCO
# 63      ARGENTINA        FRANCE
#
# [64 rows x 2 columns]

# %%
import seaborn as sns
sns.set()

graph=sns.scatterplot(x='team1',y='team2',data=df1)
graph
# Out:
# <AxesSubplot:xlabel='team1', ylabel='team2'>
